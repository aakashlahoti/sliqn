# %%
import numpy as np
from matplotlib import pyplot as plt
import numpy.linalg as LA

# %%
epochs = 1000
gstop = 1e-7
max_iter = 30
def find_minima(x_0, A, sum_A, b, sum_b, B, sum_B_inv, all_z, all_Bz, all_g, sum_Bz, sum_g):
    global x_star
    x_star = np.zeros(d)
    global conv_iters
    conv_iters = 1
    print("Started IQN!")
    x = np.copy(x_0)
    
    for t in range(epochs):
        for i in range(n):
            z_i = all_z[i]
            B_i = B[:, :, i]

            x = sum_B_inv @ (sum_Bz - sum_g)

            s = x - z_i # s denotes the variable variation
            curr_grad_i = (A[i] @ x + b[i]) # denotes gradient of f_i at current x
            y = curr_grad_i - all_g[i] # y denotes the gradient variation

            # Update B (take a BFGS step in the descent direction)
            Bs = B_i @ s
            B[:, :, i] = B_i + np.outer(y, y.T) / np.dot(y, s) - np.outer(Bs, Bs.T) / np.dot(s, Bs)

            # Update Binv in O(d ^ 2) time
            Binv_y = sum_B_inv @ y
            Z = sum_B_inv - np.outer(Binv_y, Binv_y.T) / (np.dot(s, y) + np.dot(y, Binv_y))
            ZBs = Z @ Bs
            sum_B_inv = Z + np.outer(ZBs, ZBs.T) / (np.dot(s, Bs) - np.dot(Bs, ZBs))
            sum_g = sum_g + y
            sum_Bz = sum_Bz + (B[:, :, i] @ x) - all_Bz[i]

            # Maintain the old variables
            all_Bz[i] = B[:, :, i] @ x
            all_z[i] = x
            all_g[i] = curr_grad_i
    
        gnorm = LA.norm(sum_A @ x + sum_b) / n
        if gnorm < gstop:
            print("Found minima after t : {} epochs".format(t))
            x_star = x
            conv_iters = t
            break
        print("(IQN) Current epoch : {} Current gnorm : {}".format(t, gnorm))
        
def IQN(x_0, A, sum_A, b, sum_b, B, sum_B_inv, all_z, all_Bz, all_g, sum_Bz, sum_g):
    y_axis_iqn = np.zeros(max_iter)
    print("Started IQN!")
    x = np.copy(x_0)
    for t in range(max_iter):
        for i in range(n):
            z_i = all_z[i]
            B_i = B[:, :, i]

            x = sum_B_inv @ (sum_Bz - sum_g)

            s = x - z_i # s denotes the variable variation
            curr_grad_i = (A[i] @ x + b[i]) # denotes gradient of f_i at current x
            y = curr_grad_i - all_g[i] # y denotes the gradient variation

            # Update B (take a BFGS step in the descent direction)
            Bs = B_i @ s
            B[:, :, i] = B_i + np.outer(y, y.T) / np.dot(y, s) - np.outer(Bs, Bs.T) / np.dot(s, Bs)

            # Update Binv in O(d ^ 2) time
            Binv_y = sum_B_inv @ y
            Z = sum_B_inv - np.outer(Binv_y, Binv_y.T) / (np.dot(s, y) + np.dot(y, Binv_y))
            ZBs = Z @ Bs
            sum_B_inv = Z + np.outer(ZBs, ZBs.T) / (np.dot(s, Bs) - np.dot(Bs, ZBs))
            sum_g = sum_g + y
            sum_Bz = sum_Bz + (B[:, :, i] @ x) - all_Bz[i]

            # Maintain the old variables
            all_Bz[i] = B[:, :, i] @ x
            all_z[i] = x
            all_g[i] = curr_grad_i
        
        gnorm = LA.norm(sum_A @ x + sum_b) / n 
        y_axis_iqn[t] = LA.norm(x - x_star) / LA.norm(x_0 - x_star)
        print("(IQN) Current epoch : {} Current gradient norm : {}".format(t, gnorm))
        
    return y_axis_iqn[max_iter - 1]

def Greedy_IQN(x_0, A, sum_A, b, sum_b, B, sum_B_inv, all_z, all_Bz, all_g, sum_Bz, sum_g, args):
    sum_B = LA.inv(sum_B_inv)
    print("Started Greedy IQN!")
    y_axis_giqn = np.zeros(max_iter)
    x = np.copy(x_0)
    M = 0 # tune this to change the convergence rate
    for t in range(max_iter):
        for i in range(n):
            z_i = all_z[i]
            B_i = B[:, :, i]

            x = sum_B_inv @ (sum_Bz - sum_g)

            s = x - z_i # s denotes the variable variation
            r = np.sqrt(np.dot(s, A[i] @ s)) # compute r = sqrt(s^T * Actual Hessian * s)
            
            curr_grad_i = A[i] @ x + b[i] # denotes gradient of f_i at current x
            y = curr_grad_i - all_g[i] # y denotes the gradient variation
            
            B_upon_A = np.diagonal(B_i) / np.diagonal(A[i])
            max_idx = np.argmax(B_upon_A)
            greedy_vec = np.zeros(d)
            greedy_vec[max_idx] = 1
            actual_hess_col = A[i][max_idx]
            
            Q = (1 + M * r) * B_i
            Qu = Q[max_idx] # Q @ u
            B_i = Q - np.outer(Qu, Qu.T) / Qu[max_idx] + np.outer(actual_hess_col, actual_hess_col.T) / actual_hess_col[max_idx]

            
            if args == 0:
                # M = 0, so this update can be done in O(d ^ 2) time
                psi2_inv_Qu = sum_B_inv @ Qu
                psi1_inv = sum_B_inv + np.outer(psi2_inv_Qu, psi2_inv_Qu.T) / (
                            Qu[max_idx] - np.dot(Qu, psi2_inv_Qu))

                psi1_inv_hessu = psi1_inv @ actual_hess_col
                sum_B_inv = psi1_inv - np.outer(psi1_inv_hessu, psi1_inv_hessu.T) / (
                            actual_hess_col[max_idx] + np.dot(actual_hess_col, psi1_inv_hessu))
                
            else:
                sum_B = sum_B + B_i - B[:, :, i]
                sum_B_inv = LA.inv(sum_B)
            
            sum_g = sum_g + y
            sum_Bz = sum_Bz + (B_i @ x) - all_Bz[i]

            # Maintain the old variables
            B[:, :, i] = B_i
            all_Bz[i] = B_i @ x
            all_z[i] = np.copy(x)
            all_g[i] = curr_grad_i
            
        y_axis_giqn[t] = LA.norm(x - x_star) / LA.norm(x_0 - x_star)
        gnorm = LA.norm(sum_A @ x + sum_b) / n  
        print("(Greedy IQN) Current epoch : {} Current gradient norm : {}".format(t, gnorm))
        
    return y_axis_giqn[max_iter - 1]


def Hybrid_IQN(x_0, A, sum_A, b, sum_b, B, sum_B_inv, all_z, all_Bz, all_g, sum_Bz, sum_g, args):
    sum_B = LA.inv(sum_B_inv)
    print("Started Hybrid IQN!")
    x = np.copy(x_0)
    y_axis_hiqn = np.zeros(max_iter) 
    M = 0 # tune this to change the convergence rate
    for t in range(max_iter):
        for i in range(n):
            z_i = all_z[i]
            B_i = B[:, :, i]

            x = sum_B_inv @ (sum_Bz - sum_g)

            s = x - z_i # s denotes the variable variation
            r = np.sqrt(np.dot(s, A[i] @ s)) # compute r = sqrt(s^T * Actual Hessian * s)
            
            curr_grad_i = A[i] @ x + b[i] # denotes gradient of f_i at current x
            y = curr_grad_i - all_g[i] # y denotes the gradient variation
            
            # Update B (take a BFGS step in the descent direction)
            Bs = B_i @ s
            B_intermediate = B_i + np.outer(y, y.T) / np.dot(y, s) - np.outer(Bs, Bs.T) / np.dot(s, Bs)
            
            
            B_upon_A = np.diagonal(B_intermediate) / np.diagonal(A[i])
            max_idx = np.argmax(B_upon_A)
            greedy_vec = np.zeros(d)
            greedy_vec[max_idx] = 1
            actual_hess_col = A[i][max_idx]
            
            Q = ((1 + 0.5 * M * r) ** 2) * B_intermediate
            Qu = Q[max_idx] # Q @ u
            B_final = Q - np.outer(Qu, Qu.T) / Qu[max_idx] + np.outer(actual_hess_col, actual_hess_col.T) / actual_hess_col[max_idx]

            
            if args == 0:
                # The following updates are meant to update sum_B_inv in O(d ^ 2) time
                # Since M = 0, sum_B_inv = inv(sum D_i(t - 1)) (in the draft)
                sum_B_inv_y = sum_B_inv @ y
                psi3_inv = sum_B_inv - np.outer(sum_B_inv_y, sum_B_inv_y.T) / (
                    np.dot(y, s) + np.dot(y, sum_B_inv_y))

                psi3_inv_Bs = psi3_inv @ Bs
                psi2_inv = psi3_inv + np.outer(psi3_inv_Bs, psi3_inv_Bs.T) / (
                            np.dot(s, Bs) - np.dot(Bs, psi3_inv_Bs))

                psi2_inv_Qu = psi2_inv @ Qu
                psi1_inv = psi2_inv + np.outer(psi2_inv_Qu, psi2_inv_Qu.T) / (
                            Qu[max_idx] - np.dot(Qu, psi2_inv_Qu))

                psi1_inv_hessu = psi1_inv @ actual_hess_col
                sum_B_inv = psi1_inv - np.outer(psi1_inv_hessu, psi1_inv_hessu.T) / (
                            actual_hess_col[max_idx] + np.dot(actual_hess_col, psi1_inv_hessu))
            
            else:
                # Possible to do it in O(d ^ 2) through lazy propagration (but skipped)
                sum_B = sum_B + B_final - B[:, :, i]
                sum_B_inv = LA.inv(sum_B)
            
            sum_g = sum_g + y
            sum_Bz = sum_Bz + (B_final @ x) - all_Bz[i]

            # Maintain the old variables
            B[:, :, i] = B_final
            all_Bz[i] = B_final @ x
            all_z[i] = np.copy(x)
            all_g[i] = curr_grad_i
        
        y_axis_hiqn[t] = LA.norm(x - x_star) / LA.norm(x_0 - x_star)
        gnorm = LA.norm(sum_A @ x + sum_b) / n  
        print("(Hybrid IQN) Current epoch : {} Current gradient norm : {}".format(t, gnorm))

    return y_axis_hiqn[max_iter - 1]

# %%
# Generate data 
n = 50 # number of functions
xi = 2 # condition number fixed
dimension_arr = [100, 250, 400] # Dimension varied
plot_iqn, plot_giqn, plot_hiqn = np.zeros(len(dimension_arr)), np.zeros(len(dimension_arr)), np.zeros(len(dimension_arr))
cond = []

for iter in range(len(dimension_arr)):
    A = []
    [L, mu] = [1e-10, 1e10]
    d = dimension_arr[iter]
    b = np.zeros((n, d))
    for i in range(n):
        a = np.zeros(d)
        # Sample the first d / 2 elements from [1, 10 ** (xi/2)]
        a[0: int(d / 2)] = np.random.uniform(1, 10 ** (0.5 * xi), size = int(d / 2))


        # Sample the next d / 2 elements from [10 ** (-xi/2), 1]
        a[int(d / 2): d] = np.random.uniform(10 ** (-0.5 * xi), 1, size = int(d / 2))

        L = max(L, np.max(a))
        mu = min(mu, np.min(a))
        A.append(np.diag(a))

        # b_i is generated by sampling from the box [0, 1000] ^ {d}
        b[i] = np.random.uniform(0, 1000, d)

    cond_no = L / mu
    cond.append(cond_no)
    sum_A = sum(A)
    sum_b = np.sum(b, axis = 0)

    x_0 = 0.1 * np.random.rand(d)
    B_approx = np.zeros((d, d, n))
    for i in range(n):
    #     B_approx[:, :, i] = 10 ** (0.75 * xi) * np.identity(d)
          B_approx[:, :, i] = L * np.identity(d)
    sum_B_inverse = LA.inv(np.sum(B_approx, 2))

    all_z_vals = np.zeros((n, d))
    for i in range(n):
        all_z_vals[i] = np.copy(x_0)


    all_gradients = np.zeros((n, d))
    for i in range(n):
        all_gradients[i] = (A[i] @ x_0) + b[i]
    sum_gradients = np.sum(all_gradients, axis = 0)

    all_Bz_vals = np.zeros((n, d))
    for i in range(n):
        all_Bz_vals[i] = B_approx[:, :, i] @ x_0
    sum_Bz_vals = np.sum(all_Bz_vals, axis = 0)

    initial_gradient_norm = LA.norm(sum_A @ x_0 + sum_b) / n
    print("Initial gradient norm : {}".format(initial_gradient_norm))

    find_minima(np.copy(x_0), np.copy(A), np.copy(sum_A), np.copy(b), np.copy(sum_b), np.copy(B_approx), np.copy(sum_B_inverse), 
        np.copy(all_z_vals), np.copy(all_Bz_vals), 
        np.copy(all_gradients), np.copy(sum_Bz_vals), np.copy(sum_gradients))

    plot_iqn[iter] = IQN(np.copy(x_0), np.copy(A), np.copy(sum_A), np.copy(b), np.copy(sum_b), np.copy(B_approx), np.copy(sum_B_inverse), 
        np.copy(all_z_vals), np.copy(all_Bz_vals), 
        np.copy(all_gradients), np.copy(sum_Bz_vals), np.copy(sum_gradients))


    plot_giqn[iter] = Greedy_IQN(np.copy(x_0), np.copy(A), np.copy(sum_A), np.copy(b), np.copy(sum_b), np.copy(B_approx), np.copy(sum_B_inverse), 
        np.copy(all_z_vals), np.copy(all_Bz_vals), 
        np.copy(all_gradients), np.copy(sum_Bz_vals), np.copy(sum_gradients), 1)

    plot_hiqn[iter] = Hybrid_IQN(np.copy(x_0), np.copy(A), np.copy(sum_A), np.copy(b), np.copy(sum_b), np.copy(B_approx), np.copy(sum_B_inverse), 
        np.copy(all_z_vals), np.copy(all_Bz_vals), 
        np.copy(all_gradients), np.copy(sum_Bz_vals), np.copy(sum_gradients), 0)
# Out:
# Initial gradient norm : 5016.60720936796
# Started IQN!
# (IQN) Current epoch : 0 Current gnorm : 3338.136610541331
# (IQN) Current epoch : 1 Current gnorm : 3310.5620726473153
# (IQN) Current epoch : 2 Current gnorm : 624.7686658157902
# (IQN) Current epoch : 3 Current gnorm : 146.09315603654804
# (IQN) Current epoch : 4 Current gnorm : 125.81290988618991
# (IQN) Current epoch : 5 Current gnorm : 102.82615557500921
# (IQN) Current epoch : 6 Current gnorm : 30.25910121864346
# (IQN) Current epoch : 7 Current gnorm : 8.434274789593895
# (IQN) Current epoch : 8 Current gnorm : 7.2222766369676945
# (IQN) Current epoch : 9 Current gnorm : 6.268125699306553
# (IQN) Current epoch : 10 Current gnorm : 2.031955878419096
# (IQN) Current epoch : 11 Current gnorm : 0.5482672596961419
# (IQN) Current epoch : 12 Current gnorm : 0.38049275902737323
# (IQN) Current epoch : 13 Current gnorm : 0.3931502868953077
# (IQN) Current epoch : 14 Current gnorm : 0.1614490068348346
# (IQN) Current epoch : 15 Current gnorm : 0.029401609647646217
# (IQN) Current epoch : 16 Current gnorm : 0.01846086027149003
# (IQN) Current epoch : 17 Current gnorm : 0.019176077447302157
# (IQN) Current epoch : 18 Current gnorm : 0.009245894666773348
# (IQN) Current epoch : 19 Current gnorm : 0.0014428441927174548
# (IQN) Current epoch : 20 Current gnorm : 0.0008825129098478861
# (IQN) Current epoch : 21 Current gnorm : 0.0008843332269273669
# (IQN) Current epoch : 22 Current gnorm : 0.0004419505921030413
# (IQN) Current epoch : 23 Current gnorm : 7.86945473949616e-05
# (IQN) Current epoch : 24 Current gnorm : 4.0589092206020394e-05
# (IQN) Current epoch : 25 Current gnorm : 4.07331527847849e-05
# (IQN) Current epoch : 26 Current gnorm : 2.4767982471025693e-05
# (IQN) Current epoch : 27 Current gnorm : 5.159797589899749e-06
# (IQN) Current epoch : 28 Current gnorm : 1.6477419684881427e-06
# (IQN) Current epoch : 29 Current gnorm : 1.3929669971041964e-06
# (IQN) Current epoch : 30 Current gnorm : 1.2666688072031044e-06
# (IQN) Current epoch : 31 Current gnorm : 3.3175726689063326e-07
# Found minima after t : 32 epochs
# Started IQN!
# (IQN) Current epoch : 0 Current gradient norm : 3338.136610541331
# (IQN) Current epoch : 1 Current gradient norm : 3310.5620726473153
# (IQN) Current epoch : 2 Current gradient norm : 624.7686658157902
# (IQN) Current epoch : 3 Current gradient norm : 146.09315603654804
# (IQN) Current epoch : 4 Current gradient norm : 125.81290988618991
# (IQN) Current epoch : 5 Current gradient norm : 102.82615557500921
# (IQN) Current epoch : 6 Current gradient norm : 30.25910121864346
# (IQN) Current epoch : 7 Current gradient norm : 8.434274789593895
# (IQN) Current epoch : 8 Current gradient norm : 7.2222766369676945
# (IQN) Current epoch : 9 Current gradient norm : 6.268125699306553
# (IQN) Current epoch : 10 Current gradient norm : 2.031955878419096
# (IQN) Current epoch : 11 Current gradient norm : 0.5482672596961419
# (IQN) Current epoch : 12 Current gradient norm : 0.38049275902737323
# (IQN) Current epoch : 13 Current gradient norm : 0.3931502868953077
# (IQN) Current epoch : 14 Current gradient norm : 0.1614490068348346
# (IQN) Current epoch : 15 Current gradient norm : 0.029401609647646217
# (IQN) Current epoch : 16 Current gradient norm : 0.01846086027149003
# (IQN) Current epoch : 17 Current gradient norm : 0.019176077447302157
# (IQN) Current epoch : 18 Current gradient norm : 0.009245894666773348
# (IQN) Current epoch : 19 Current gradient norm : 0.0014428441927174548
# (IQN) Current epoch : 20 Current gradient norm : 0.0008825129098478861
# (IQN) Current epoch : 21 Current gradient norm : 0.0008843332269273669
# (IQN) Current epoch : 22 Current gradient norm : 0.0004419505921030413
# (IQN) Current epoch : 23 Current gradient norm : 7.86945473949616e-05
# (IQN) Current epoch : 24 Current gradient norm : 4.0589092206020394e-05
# (IQN) Current epoch : 25 Current gradient norm : 4.07331527847849e-05
# (IQN) Current epoch : 26 Current gradient norm : 2.4767982471025693e-05
# (IQN) Current epoch : 27 Current gradient norm : 5.159797589899749e-06
# (IQN) Current epoch : 28 Current gradient norm : 1.6477419684881427e-06
# (IQN) Current epoch : 29 Current gradient norm : 1.3929669971041964e-06
# Started Greedy IQN!
# (Greedy IQN) Current epoch : 0 Current gradient norm : 3083.4956840256136
# (Greedy IQN) Current epoch : 1 Current gradient norm : 2716.0815126286384
# (Greedy IQN) Current epoch : 2 Current gradient norm : 2415.447332452505
# (Greedy IQN) Current epoch : 3 Current gradient norm : 2144.7712627744595
# (Greedy IQN) Current epoch : 4 Current gradient norm : 1900.058535616949
# (Greedy IQN) Current epoch : 5 Current gradient norm : 1678.7319089769842
# (Greedy IQN) Current epoch : 6 Current gradient norm : 1479.1069980180719
# (Greedy IQN) Current epoch : 7 Current gradient norm : 1299.4304628009031
# (Greedy IQN) Current epoch : 8 Current gradient norm : 1138.189245859219
# (Greedy IQN) Current epoch : 9 Current gradient norm : 993.8604354349527
# (Greedy IQN) Current epoch : 10 Current gradient norm : 864.9445187094938
# (Greedy IQN) Current epoch : 11 Current gradient norm : 750.1000483278492
# (Greedy IQN) Current epoch : 12 Current gradient norm : 648.025154392502
# (Greedy IQN) Current epoch : 13 Current gradient norm : 557.6470393822564
# (Greedy IQN) Current epoch : 14 Current gradient norm : 478.0802901893451
# (Greedy IQN) Current epoch : 15 Current gradient norm : 408.11765588133954
# (Greedy IQN) Current epoch : 16 Current gradient norm : 346.95709440360463
# (Greedy IQN) Current epoch : 17 Current gradient norm : 293.46164966990904
# (Greedy IQN) Current epoch : 18 Current gradient norm : 246.8120504713269
# (Greedy IQN) Current epoch : 19 Current gradient norm : 206.29197378870813
# (Greedy IQN) Current epoch : 20 Current gradient norm : 171.38851398576625
# (Greedy IQN) Current epoch : 21 Current gradient norm : 141.53607834250184
# (Greedy IQN) Current epoch : 22 Current gradient norm : 116.12938430975797
# (Greedy IQN) Current epoch : 23 Current gradient norm : 94.60944145954981
# (Greedy IQN) Current epoch : 24 Current gradient norm : 76.5154092040778
# (Greedy IQN) Current epoch : 25 Current gradient norm : 61.34544345952239
# (Greedy IQN) Current epoch : 26 Current gradient norm : 48.76235705524082
# (Greedy IQN) Current epoch : 27 Current gradient norm : 38.373315673083965
# (Greedy IQN) Current epoch : 28 Current gradient norm : 29.900581780387565
# (Greedy IQN) Current epoch : 29 Current gradient norm : 23.036822705716236
# Started Hybrid IQN!
# (Hybrid IQN) Current epoch : 0 Current gradient norm : 3332.621548380397
# (Hybrid IQN) Current epoch : 1 Current gradient norm : 3288.826707902651
# (Hybrid IQN) Current epoch : 2 Current gradient norm : 611.3014628581905
# (Hybrid IQN) Current epoch : 3 Current gradient norm : 139.38893412401373
# (Hybrid IQN) Current epoch : 4 Current gradient norm : 118.65811919574188
# (Hybrid IQN) Current epoch : 5 Current gradient norm : 93.01123613778692
# (Hybrid IQN) Current epoch : 6 Current gradient norm : 26.28846800176633
# (Hybrid IQN) Current epoch : 7 Current gradient norm : 7.09324925397531
# (Hybrid IQN) Current epoch : 8 Current gradient norm : 5.955762537627206
# (Hybrid IQN) Current epoch : 9 Current gradient norm : 4.7658419170655035
# (Hybrid IQN) Current epoch : 10 Current gradient norm : 1.416583359702921
# (Hybrid IQN) Current epoch : 11 Current gradient norm : 0.3508349668250229
# (Hybrid IQN) Current epoch : 12 Current gradient norm : 0.21874261022375902
# (Hybrid IQN) Current epoch : 13 Current gradient norm : 0.21279558144083865
# (Hybrid IQN) Current epoch : 14 Current gradient norm : 0.07367261128817866
# (Hybrid IQN) Current epoch : 15 Current gradient norm : 0.012428775420219116
# (Hybrid IQN) Current epoch : 16 Current gradient norm : 0.006531606095526299
# (Hybrid IQN) Current epoch : 17 Current gradient norm : 0.0062205609739271915
# (Hybrid IQN) Current epoch : 18 Current gradient norm : 0.0022648727234312145
# (Hybrid IQN) Current epoch : 19 Current gradient norm : 0.0005163921272016938
# (Hybrid IQN) Current epoch : 20 Current gradient norm : 0.00041211101235518176
# (Hybrid IQN) Current epoch : 21 Current gradient norm : 0.0001898334026393396
# (Hybrid IQN) Current epoch : 22 Current gradient norm : 5.954716109468997e-05
# (Hybrid IQN) Current epoch : 23 Current gradient norm : 3.879986822803271e-05
# (Hybrid IQN) Current epoch : 24 Current gradient norm : 1.7869349148285212e-05
# (Hybrid IQN) Current epoch : 25 Current gradient norm : 4.10860771558843e-06
# (Hybrid IQN) Current epoch : 26 Current gradient norm : 2.808159734369871e-06
# (Hybrid IQN) Current epoch : 27 Current gradient norm : 1.502953466213794e-06
# (Hybrid IQN) Current epoch : 28 Current gradient norm : 3.752704391058451e-07
# (Hybrid IQN) Current epoch : 29 Current gradient norm : 1.8286606517537668e-07
# Initial gradient norm : 7889.757434409544
# Started IQN!
# (IQN) Current epoch : 0 Current gnorm : 5286.2391571629605
# (IQN) Current epoch : 1 Current gnorm : 5195.854721441893
# (IQN) Current epoch : 2 Current gnorm : 969.2347418105667
# (IQN) Current epoch : 3 Current gnorm : 253.8863746889041
# (IQN) Current epoch : 4 Current gnorm : 226.0087724484025
# (IQN) Current epoch : 5 Current gnorm : 169.9239064071593
# (IQN) Current epoch : 6 Current gnorm : 45.454133492265946
# (IQN) Current epoch : 7 Current gnorm : 16.13908369116703
# (IQN) Current epoch : 8 Current gnorm : 14.92237646390869
# (IQN) Current epoch : 9 Current gnorm : 10.448569297236425
# (IQN) Current epoch : 10 Current gnorm : 2.402955823034884
# (IQN) Current epoch : 11 Current gnorm : 1.1178055838557523
# (IQN) Current epoch : 12 Current gnorm : 1.051215663050842
# (IQN) Current epoch : 13 Current gnorm : 0.6998204027935055
# (IQN) Current epoch : 14 Current gnorm : 0.14282203146976274
# (IQN) Current epoch : 15 Current gnorm : 0.0651460525383556
# (IQN) Current epoch : 16 Current gnorm : 0.06290309691318866
# (IQN) Current epoch : 17 Current gnorm : 0.0386566082504274
# (IQN) Current epoch : 18 Current gnorm : 0.008152570134220646
# (IQN) Current epoch : 19 Current gnorm : 0.0037399947091514064
# (IQN) Current epoch : 20 Current gnorm : 0.003689399349241186
# (IQN) Current epoch : 21 Current gnorm : 0.002221942055031907
# (IQN) Current epoch : 22 Current gnorm : 0.0004389673197397106
# (IQN) Current epoch : 23 Current gnorm : 0.00020026026131239448
# (IQN) Current epoch : 24 Current gnorm : 0.00018847908509928932
# (IQN) Current epoch : 25 Current gnorm : 0.00014502281659900776
# (IQN) Current epoch : 26 Current gnorm : 3.696023268949126e-05
# (IQN) Current epoch : 27 Current gnorm : 1.083622973978159e-05
# (IQN) Current epoch : 28 Current gnorm : 7.798176809289681e-06
# (IQN) Current epoch : 29 Current gnorm : 7.934845905868292e-06
# (IQN) Current epoch : 30 Current gnorm : 3.0996467724553473e-06
# (IQN) Current epoch : 31 Current gnorm : 5.614885143202235e-07
# (IQN) Current epoch : 32 Current gnorm : 3.624806156733963e-07
# (IQN) Current epoch : 33 Current gnorm : 3.6955899416120724e-07
# (IQN) Current epoch : 34 Current gnorm : 1.818877992555153e-07
# Found minima after t : 35 epochs
# Started IQN!
# (IQN) Current epoch : 0 Current gradient norm : 5286.2391571629605
# (IQN) Current epoch : 1 Current gradient norm : 5195.854721441893
# (IQN) Current epoch : 2 Current gradient norm : 969.2347418105667
# (IQN) Current epoch : 3 Current gradient norm : 253.8863746889041
# (IQN) Current epoch : 4 Current gradient norm : 226.0087724484025
# (IQN) Current epoch : 5 Current gradient norm : 169.9239064071593
# (IQN) Current epoch : 6 Current gradient norm : 45.454133492265946
# (IQN) Current epoch : 7 Current gradient norm : 16.13908369116703
# (IQN) Current epoch : 8 Current gradient norm : 14.92237646390869
# (IQN) Current epoch : 9 Current gradient norm : 10.448569297236425
# (IQN) Current epoch : 10 Current gradient norm : 2.402955823034884
# (IQN) Current epoch : 11 Current gradient norm : 1.1178055838557523
# (IQN) Current epoch : 12 Current gradient norm : 1.051215663050842
# (IQN) Current epoch : 13 Current gradient norm : 0.6998204027935055
# (IQN) Current epoch : 14 Current gradient norm : 0.14282203146976274
# (IQN) Current epoch : 15 Current gradient norm : 0.0651460525383556
# (IQN) Current epoch : 16 Current gradient norm : 0.06290309691318866
# (IQN) Current epoch : 17 Current gradient norm : 0.0386566082504274
# (IQN) Current epoch : 18 Current gradient norm : 0.008152570134220646
# (IQN) Current epoch : 19 Current gradient norm : 0.0037399947091514064
# (IQN) Current epoch : 20 Current gradient norm : 0.003689399349241186
# (IQN) Current epoch : 21 Current gradient norm : 0.002221942055031907
# (IQN) Current epoch : 22 Current gradient norm : 0.0004389673197397106
# (IQN) Current epoch : 23 Current gradient norm : 0.00020026026131239448
# (IQN) Current epoch : 24 Current gradient norm : 0.00018847908509928932
# (IQN) Current epoch : 25 Current gradient norm : 0.00014502281659900776
# (IQN) Current epoch : 26 Current gradient norm : 3.696023268949126e-05
# (IQN) Current epoch : 27 Current gradient norm : 1.083622973978159e-05
# (IQN) Current epoch : 28 Current gradient norm : 7.798176809289681e-06
# (IQN) Current epoch : 29 Current gradient norm : 7.934845905868292e-06
# Started Greedy IQN!
# (Greedy IQN) Current epoch : 0 Current gradient norm : 4863.499904474752
# (Greedy IQN) Current epoch : 1 Current gradient norm : 4295.255742466009
# (Greedy IQN) Current epoch : 2 Current gradient norm : 3832.8431431974873
# (Greedy IQN) Current epoch : 3 Current gradient norm : 3420.475971894348
# (Greedy IQN) Current epoch : 4 Current gradient norm : 3050.249035582439
# (Greedy IQN) Current epoch : 5 Current gradient norm : 2717.8641104792064
# (Greedy IQN) Current epoch : 6 Current gradient norm : 2419.566290362974
# (Greedy IQN) Current epoch : 7 Current gradient norm : 2151.9840523877956
# (Greedy IQN) Current epoch : 8 Current gradient norm : 1912.1213391191588
# (Greedy IQN) Current epoch : 9 Current gradient norm : 1697.4304051487748
# (Greedy IQN) Current epoch : 10 Current gradient norm : 1505.414444115419
# (Greedy IQN) Current epoch : 11 Current gradient norm : 1333.8417624863246
# (Greedy IQN) Current epoch : 12 Current gradient norm : 1180.5514540152008
# (Greedy IQN) Current epoch : 13 Current gradient norm : 1043.7957707271578
# (Greedy IQN) Current epoch : 14 Current gradient norm : 921.9012057514861
# (Greedy IQN) Current epoch : 15 Current gradient norm : 813.3562748091633
# (Greedy IQN) Current epoch : 16 Current gradient norm : 716.7785035731345
# (Greedy IQN) Current epoch : 17 Current gradient norm : 630.9652193157158
# (Greedy IQN) Current epoch : 18 Current gradient norm : 554.8573524742283
# (Greedy IQN) Current epoch : 19 Current gradient norm : 487.355881186693
# (Greedy IQN) Current epoch : 20 Current gradient norm : 427.57757776987904
# (Greedy IQN) Current epoch : 21 Current gradient norm : 374.65683769147205
# (Greedy IQN) Current epoch : 22 Current gradient norm : 327.865401433943
# (Greedy IQN) Current epoch : 23 Current gradient norm : 286.58453766042015
# (Greedy IQN) Current epoch : 24 Current gradient norm : 250.1986929810751
# (Greedy IQN) Current epoch : 25 Current gradient norm : 218.14401588205064
# (Greedy IQN) Current epoch : 26 Current gradient norm : 189.95409346590665
# (Greedy IQN) Current epoch : 27 Current gradient norm : 165.15596261971575
# (Greedy IQN) Current epoch : 28 Current gradient norm : 143.37504881771542
# (Greedy IQN) Current epoch : 29 Current gradient norm : 124.2951361924561
# Started Hybrid IQN!
# (Hybrid IQN) Current epoch : 0 Current gradient norm : 5282.735344501648
# (Hybrid IQN) Current epoch : 1 Current gradient norm : 5182.413630167435
# (Hybrid IQN) Current epoch : 2 Current gradient norm : 960.2125951680273
# (Hybrid IQN) Current epoch : 3 Current gradient norm : 247.61479880638993
# (Hybrid IQN) Current epoch : 4 Current gradient norm : 219.31699461943612
# (Hybrid IQN) Current epoch : 5 Current gradient norm : 161.9642417103605
# (Hybrid IQN) Current epoch : 6 Current gradient norm : 42.33610121544256
# (Hybrid IQN) Current epoch : 7 Current gradient norm : 13.907008637628815
# (Hybrid IQN) Current epoch : 8 Current gradient norm : 12.59931830951616
# (Hybrid IQN) Current epoch : 9 Current gradient norm : 8.969801620167981
# (Hybrid IQN) Current epoch : 10 Current gradient norm : 1.9856331818275788
# (Hybrid IQN) Current epoch : 11 Current gradient norm : 0.6955338892803731
# (Hybrid IQN) Current epoch : 12 Current gradient norm : 0.5976508630197521
# (Hybrid IQN) Current epoch : 13 Current gradient norm : 0.48218219867317885
# (Hybrid IQN) Current epoch : 14 Current gradient norm : 0.10958135142783977
# (Hybrid IQN) Current epoch : 15 Current gradient norm : 0.029628933921511294
# (Hybrid IQN) Current epoch : 16 Current gradient norm : 0.024959689609573118
# (Hybrid IQN) Current epoch : 17 Current gradient norm : 0.020802947056162088
# (Hybrid IQN) Current epoch : 18 Current gradient norm : 0.005552324331385515
# (Hybrid IQN) Current epoch : 19 Current gradient norm : 0.001209153895872376
# (Hybrid IQN) Current epoch : 20 Current gradient norm : 0.0009676562872713791
# (Hybrid IQN) Current epoch : 21 Current gradient norm : 0.0008358482430887021
# (Hybrid IQN) Current epoch : 22 Current gradient norm : 0.00025408048254700345
# (Hybrid IQN) Current epoch : 23 Current gradient norm : 5.3681229290558806e-05
# (Hybrid IQN) Current epoch : 24 Current gradient norm : 2.891917631378078e-05
# (Hybrid IQN) Current epoch : 25 Current gradient norm : 2.7873482798271677e-05
# (Hybrid IQN) Current epoch : 26 Current gradient norm : 1.4576959509666427e-05
# (Hybrid IQN) Current epoch : 27 Current gradient norm : 2.935948296737603e-06
# (Hybrid IQN) Current epoch : 28 Current gradient norm : 8.436133068088754e-07
# (Hybrid IQN) Current epoch : 29 Current gradient norm : 6.866031180486971e-07
# Initial gradient norm : 10013.318631109376
# Started IQN!
# (IQN) Current epoch : 0 Current gnorm : 6724.597826502735
# (IQN) Current epoch : 1 Current gnorm : 6664.295831917412
# (IQN) Current epoch : 2 Current gnorm : 1262.4945514823416
# (IQN) Current epoch : 3 Current gnorm : 332.12575308245613
# (IQN) Current epoch : 4 Current gnorm : 300.37218655772756
# (IQN) Current epoch : 5 Current gnorm : 234.69973337302284
# (IQN) Current epoch : 6 Current gnorm : 65.0596117304713
# (IQN) Current epoch : 7 Current gnorm : 23.647319861392926
# (IQN) Current epoch : 8 Current gnorm : 22.266323481196178
# (IQN) Current epoch : 9 Current gnorm : 17.37129675195595
# (IQN) Current epoch : 10 Current gnorm : 4.409039159884439
# (IQN) Current epoch : 11 Current gnorm : 2.0255637452647304
# (IQN) Current epoch : 12 Current gnorm : 1.9133336856655663
# (IQN) Current epoch : 13 Current gnorm : 1.5128264640031366
# (IQN) Current epoch : 14 Current gnorm : 0.39294099092162676
# (IQN) Current epoch : 15 Current gnorm : 0.16621426315852283
# (IQN) Current epoch : 16 Current gnorm : 0.15588148277922298
# (IQN) Current epoch : 17 Current gnorm : 0.12773223616855564
# (IQN) Current epoch : 18 Current gnorm : 0.033998149657458565
# (IQN) Current epoch : 19 Current gnorm : 0.011869736872330165
# (IQN) Current epoch : 20 Current gnorm : 0.010986872579292102
# (IQN) Current epoch : 21 Current gnorm : 0.009257490339164183
# (IQN) Current epoch : 22 Current gnorm : 0.0025813054694897946
# (IQN) Current epoch : 23 Current gnorm : 0.0008552844561119669
# (IQN) Current epoch : 24 Current gnorm : 0.000741301787589382
# (IQN) Current epoch : 25 Current gnorm : 0.000684740257739735
# (IQN) Current epoch : 26 Current gnorm : 0.00020428427025594623
# (IQN) Current epoch : 27 Current gnorm : 5.370469960527993e-05
# (IQN) Current epoch : 28 Current gnorm : 4.0673626636924366e-05
# (IQN) Current epoch : 29 Current gnorm : 4.172919614144428e-05
# (IQN) Current epoch : 30 Current gnorm : 1.6922291413605366e-05
# (IQN) Current epoch : 31 Current gnorm : 3.291078496311655e-06
# (IQN) Current epoch : 32 Current gnorm : 2.0869027824426154e-06
# (IQN) Current epoch : 33 Current gnorm : 2.1499048618696497e-06
# (IQN) Current epoch : 34 Current gnorm : 1.1797147826295563e-06
# (IQN) Current epoch : 35 Current gnorm : 2.2505962135035102e-07
# (IQN) Current epoch : 36 Current gnorm : 1.198012310254346e-07
# (IQN) Current epoch : 37 Current gnorm : 1.1946602677767551e-07
# Found minima after t : 38 epochs
# Started IQN!
# (IQN) Current epoch : 0 Current gradient norm : 6724.597826502735
# (IQN) Current epoch : 1 Current gradient norm : 6664.295831917412
# (IQN) Current epoch : 2 Current gradient norm : 1262.4945514823416
# (IQN) Current epoch : 3 Current gradient norm : 332.12575308245613
# (IQN) Current epoch : 4 Current gradient norm : 300.37218655772756
# (IQN) Current epoch : 5 Current gradient norm : 234.69973337302284
# (IQN) Current epoch : 6 Current gradient norm : 65.0596117304713
# (IQN) Current epoch : 7 Current gradient norm : 23.647319861392926
# (IQN) Current epoch : 8 Current gradient norm : 22.266323481196178
# (IQN) Current epoch : 9 Current gradient norm : 17.37129675195595
# (IQN) Current epoch : 10 Current gradient norm : 4.409039159884439
# (IQN) Current epoch : 11 Current gradient norm : 2.0255637452647304
# (IQN) Current epoch : 12 Current gradient norm : 1.9133336856655663
# (IQN) Current epoch : 13 Current gradient norm : 1.5128264640031366
# (IQN) Current epoch : 14 Current gradient norm : 0.39294099092162676
# (IQN) Current epoch : 15 Current gradient norm : 0.16621426315852283
# (IQN) Current epoch : 16 Current gradient norm : 0.15588148277922298
# (IQN) Current epoch : 17 Current gradient norm : 0.12773223616855564
# (IQN) Current epoch : 18 Current gradient norm : 0.033998149657458565
# (IQN) Current epoch : 19 Current gradient norm : 0.011869736872330165
# (IQN) Current epoch : 20 Current gradient norm : 0.010986872579292102
# (IQN) Current epoch : 21 Current gradient norm : 0.009257490339164183
# (IQN) Current epoch : 22 Current gradient norm : 0.0025813054694897946
# (IQN) Current epoch : 23 Current gradient norm : 0.0008552844561119669
# (IQN) Current epoch : 24 Current gradient norm : 0.000741301787589382
# (IQN) Current epoch : 25 Current gradient norm : 0.000684740257739735
# (IQN) Current epoch : 26 Current gradient norm : 0.00020428427025594623
# (IQN) Current epoch : 27 Current gradient norm : 5.370469960527993e-05
# (IQN) Current epoch : 28 Current gradient norm : 4.0673626636924366e-05
# (IQN) Current epoch : 29 Current gradient norm : 4.172919614144428e-05
# Started Greedy IQN!
# (Greedy IQN) Current epoch : 0 Current gradient norm : 6170.394622905008
# (Greedy IQN) Current epoch : 1 Current gradient norm : 5460.630475985902
# (Greedy IQN) Current epoch : 2 Current gradient norm : 4884.160711352339
# (Greedy IQN) Current epoch : 3 Current gradient norm : 4370.357522499884
# (Greedy IQN) Current epoch : 4 Current gradient norm : 3909.1526151636544
# (Greedy IQN) Current epoch : 5 Current gradient norm : 3494.978717497342
# (Greedy IQN) Current epoch : 6 Current gradient norm : 3123.1239534517704
# (Greedy IQN) Current epoch : 7 Current gradient norm : 2789.5084879230067
# (Greedy IQN) Current epoch : 8 Current gradient norm : 2490.3663553904744
# (Greedy IQN) Current epoch : 9 Current gradient norm : 2222.2747507449935
# (Greedy IQN) Current epoch : 10 Current gradient norm : 1982.1118607911433
# (Greedy IQN) Current epoch : 11 Current gradient norm : 1767.0201943079999
# (Greedy IQN) Current epoch : 12 Current gradient norm : 1574.430778455166
# (Greedy IQN) Current epoch : 13 Current gradient norm : 1402.1075916079737
# (Greedy IQN) Current epoch : 14 Current gradient norm : 1248.0007393534695
# (Greedy IQN) Current epoch : 15 Current gradient norm : 1110.2435343102811
# (Greedy IQN) Current epoch : 16 Current gradient norm : 987.1319925573454
# (Greedy IQN) Current epoch : 17 Current gradient norm : 877.1923496114651
# (Greedy IQN) Current epoch : 18 Current gradient norm : 779.0408387684197
# (Greedy IQN) Current epoch : 19 Current gradient norm : 691.4683473185542
# (Greedy IQN) Current epoch : 20 Current gradient norm : 613.3456613761709
# (Greedy IQN) Current epoch : 21 Current gradient norm : 543.7591605914223
# (Greedy IQN) Current epoch : 22 Current gradient norm : 481.7841603845662
# (Greedy IQN) Current epoch : 23 Current gradient norm : 426.61804480072584
# (Greedy IQN) Current epoch : 24 Current gradient norm : 377.51268262866523
# (Greedy IQN) Current epoch : 25 Current gradient norm : 333.8179268886847
# (Greedy IQN) Current epoch : 26 Current gradient norm : 295.00046919989296
# (Greedy IQN) Current epoch : 27 Current gradient norm : 260.50368535890976
# (Greedy IQN) Current epoch : 28 Current gradient norm : 229.89700619475533
# (Greedy IQN) Current epoch : 29 Current gradient norm : 202.73377741733486
# Started Hybrid IQN!
# (Hybrid IQN) Current epoch : 0 Current gradient norm : 6721.892081192649
# (Hybrid IQN) Current epoch : 1 Current gradient norm : 6653.690094465169
# (Hybrid IQN) Current epoch : 2 Current gradient norm : 1256.0887080620141
# (Hybrid IQN) Current epoch : 3 Current gradient norm : 329.6856754850217
# (Hybrid IQN) Current epoch : 4 Current gradient norm : 297.8029785040573
# (Hybrid IQN) Current epoch : 5 Current gradient norm : 229.05896763928712
# (Hybrid IQN) Current epoch : 6 Current gradient norm : 62.49829646175012
# (Hybrid IQN) Current epoch : 7 Current gradient norm : 22.33278029977653
# (Hybrid IQN) Current epoch : 8 Current gradient norm : 20.935966277910964
# (Hybrid IQN) Current epoch : 9 Current gradient norm : 16.032190077954862
# (Hybrid IQN) Current epoch : 10 Current gradient norm : 3.9837588422882977
# (Hybrid IQN) Current epoch : 11 Current gradient norm : 1.7754578204577944
# (Hybrid IQN) Current epoch : 12 Current gradient norm : 1.6585051802116022
# (Hybrid IQN) Current epoch : 13 Current gradient norm : 1.2958139164579432
# (Hybrid IQN) Current epoch : 14 Current gradient norm : 0.33010814148336637
# (Hybrid IQN) Current epoch : 15 Current gradient norm : 0.1340940256100102
# (Hybrid IQN) Current epoch : 16 Current gradient norm : 0.12398824583734083
# (Hybrid IQN) Current epoch : 17 Current gradient norm : 0.0989851837817453
# (Hybrid IQN) Current epoch : 18 Current gradient norm : 0.0253438080458779
# (Hybrid IQN) Current epoch : 19 Current gradient norm : 0.008173950294393894
# (Hybrid IQN) Current epoch : 20 Current gradient norm : 0.007378467673970939
# (Hybrid IQN) Current epoch : 21 Current gradient norm : 0.0059721237623001164
# (Hybrid IQN) Current epoch : 22 Current gradient norm : 0.0016042253233207824
# (Hybrid IQN) Current epoch : 23 Current gradient norm : 0.00046006616429045203
# (Hybrid IQN) Current epoch : 24 Current gradient norm : 0.0003716936538419688
# (Hybrid IQN) Current epoch : 25 Current gradient norm : 0.0003411525965790245
# (Hybrid IQN) Current epoch : 26 Current gradient norm : 0.00010272457995538068
# (Hybrid IQN) Current epoch : 27 Current gradient norm : 2.299094539852594e-05
# (Hybrid IQN) Current epoch : 28 Current gradient norm : 1.4687585004382047e-05
# (Hybrid IQN) Current epoch : 29 Current gradient norm : 1.5087095992244638e-05

# %%
print(cond)
plt.style.use("plotstyle.txt")
plt.plot(dimension_arr, plot_iqn, 'X-', label = "IQN", color='xkcd:red', markevery = 0.1)
plt.plot(dimension_arr, plot_giqn, 's-', label = "IGS", color='xkcd:azure', markevery = 0.1)
plt.plot(dimension_arr, plot_hiqn, 'D-', label = "SLIQN", color='xkcd:bright green', markevery = 0.1)
plt.yscale('log')
plt.xlim([0, 450])
plt.ylabel(r'Normalized error')
plt.xlabel(r'Dimension($d$)')
save_dir = "../Python_plots/dimension" + "_N_" + str(n) + "_dims_" + str(dimension_arr) + "_xi_" + str(xi) + "_ep_" + str(max_iter) + ".png"

plt.legend()
plt.savefig(save_dir, bbox_inches = "tight")
# Out:
# [99.76908070641929, 99.73078242598997, 99.94561890547254]
